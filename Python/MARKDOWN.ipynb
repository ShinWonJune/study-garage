# %% [markdown]
# # MARKDOWN
# ###### the smallest heading

# %% [markdown]
# ### Quoting text
#
# in the words of Abraham Lincon:
# > pardon my French

# %% [markdown]
# > pardon my French

# %% [markdown]
# _text_
#
# __text__
#
# *text*
#
# **text**

# %% [markdown]
# ### Quotind code

# %% [markdown]
# ```  안에 쓰면 코드형식으로 보여짐

# %% [markdown]
# Use `git status` to liist all new ofr midified files that ///

# %% [markdown]
# ``` python
# # python
# def hello_world():
#     print("hello world")
# ```
# ```javascript
# // Javascript
# funtion helloworld() {
# console.log("hello world");
# }
# ```

# %% [markdown]
# ### List

# %% [markdown]
# 1. Furst list item  #숫자와 콤마
#     - first nested list item # tab 과 짝대기
#         - second nested list item

# %% [markdown]
# ### Table

# %% [markdown]
# Header|Another Header| Yet Another Header
# -|-|-
# value11|value12|value13
# value21|value22|value23

# %% [markdown]
# ### Image :```![](img.png)```

# %% [markdown]
# ![](025Pikachu_LG.png)

# %% [markdown]
# ### Link ```http://www.~~```

# %% [markdown]
# [여기를 클릭하여 구글로 이동](http://www.google.com)

# %% [markdown]
# ### Inner HTML

# %% [markdown]
# ```
# <dl>
#    <dt>어쩌꾸</dt>
#    <dd></dd>
# </dl>
# ```
# <dl>definition list
#     <dt>definition list</dt>
#     <dd>덜덜하네</dd>
# <dl>definition list</dl>
# <dt>definition list</dt>
# <dd>덜덜하네</dd>

# %% [markdown]
# # 슬라이드로 사용 가능

# %% [markdown]
# # 주석

# %% [markdown]
# 오리궁댕이<sup>[1](#footnote_1)</sup>

# %% [markdown]
# <a name="footnote_1">1</a>: 오리의 궁댕이다

# %% [markdown]
# ### 분수/ 지수

# %% [markdown]
# ## $\frac{a}{b}, e^{t}, \alpha$

# %% [markdown]
# ## 밑줄

# %% [markdown]
# <u>밑줄</u>

# %% [markdown]
# ## \_ \\ \*

# %% [markdown]
# ## 스페이스, 줄바꿈
# #### 스페이스
#     - 한칸 띄움 = &nbsp;
#     - 네칸 띄움 = &emsp;
#
# #### 줄바꿈
#     - <br>
