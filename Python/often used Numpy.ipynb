# %%
import numpy as np

# %% [markdown]
# ### reshape()

# %%
# 1. x = np.reshape(a,(n, m))
# a를 nXm으로 reshape

a = np.array([1,10,2,3,4,5])
x = np.reshape(a,(2,3))
x

# %%
# 2. x = a.reshape((n, m))
# a를 nXm으로 reshape

a = np.array([1,10,2,3,4,5])
x = a.reshape((2,3))
x
